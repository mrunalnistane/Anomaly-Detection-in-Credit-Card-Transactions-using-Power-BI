# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt #visualisation

# %%
df=pd.read_csv('/content/Fraud.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0  M1979787155             0.0             0.0        0
# 1  M2044282225             0.0             0.0        0
# 2   C553264065             0.0             0.0        1
# 3    C38997010         21182.0             0.0        1
# 4  M1230701703             0.0             0.0        0

# %%
df.tail()
# Out:
#         step     type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 630889    34  CASH_IN  391369.90   C350293756     8266850.72      8658220.62
# 630890    34  CASH_IN  349874.34   C450051149     8658220.62      9008094.96
# 630891    34  CASH_IN  160272.66  C1050087317     9008094.96      9168367.61
# 630892    34  CASH_IN  343998.50   C517676378     9168367.61      9512366.11
# 630893    34  PAYMENT   17301.86    C47277715       33200.00        15898.14
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud
# 630889  C1282282294       846604.57       687206.87        0
# 630890   C550792787       673154.17       323279.83        0
# 630891  C1399373992      3592051.31      3431778.65        0
# 630892   C498599199     12100000.00     11800000.00        0
# 630893    M23270352            0.00            0.00        0

# %%
df.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# dtype: object

# %%
df.shape
# Out:
# (630894, 10)

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud'],
#       dtype='object')

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (630894, 10)

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
df.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  630894.000000  6.308940e+05   6.308940e+05    6.308940e+05
# mean       16.481322  1.619377e+05   8.880688e+05    9.080577e+05
# std         6.662352  2.699282e+05   2.961561e+06    2.998613e+06
# min         1.000000  1.000000e-01   0.000000e+00    0.000000e+00
# 25%        12.000000  1.244964e+04   0.000000e+00    0.000000e+00
# 50%        16.000000  7.624941e+04   1.744104e+04    0.000000e+00
# 75%        19.000000  2.160739e+05   1.546248e+05    1.943323e+05
# max        34.000000  1.000000e+07   3.890000e+07    3.890000e+07
#
#        oldbalanceDest  newbalanceDest        isFraud
# count    6.308940e+05    6.308940e+05  630894.000000
# mean     9.755820e+05    1.138059e+06       0.000607
# std      2.319172e+06    2.474577e+06       0.024631
# min      0.000000e+00    0.000000e+00       0.000000
# 25%      0.000000e+00    0.000000e+00       0.000000
# 50%      1.142904e+05    2.082132e+05       0.000000
# 75%      8.933429e+05    1.171927e+06       0.000000
# max      4.150000e+07    4.150000e+07       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 630894 entries, 0 to 630893
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            630894 non-null  int64
#  1   type            630894 non-null  object
#  2   amount          630894 non-null  float64
#  3   nameOrig        630894 non-null  object
#  4   oldbalanceOrg   630894 non-null  float64
#  5   newbalanceOrig  630894 non-null  float64
#  6   nameDest        630894 non-null  object
#  7   oldbalanceDest  630894 non-null  float64
#  8   newbalanceDest  630894 non-null  float64
#  9   isFraud         630894 non-null  int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 52.9+ MB
